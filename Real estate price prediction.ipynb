# %% [markdown]
# # <center>  REAL - ESTATE PRICE PREDICTION

# %% [markdown]
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ### Target : Predict the price of unit area for houses given theire features.

# %% [markdown]
# ###  Loading the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,BaggingRegressor,ExtraTreesRegressor,HistGradientBoostingRegressor
from sklearn.svm import LinearSVR
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder,StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import klib as k

# %% [markdown]
# ### Loading the dataset

# %%
data=pd.read_csv('Real estate.csv')
data
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %% [markdown]
# ### Data preprocessing
# #### Rename the columns

# %%
data=data.rename(columns={'X1 transaction date':'Transaction_date','X2 house age':'HouseAge','X3 distance to the nearest MRT station':'Distance to the nearest MRT station','X4 number of convenience stores':'Number of convenience stores','X5 latitude':'Latitude','X6 longitude':'Longitude','Y house price of unit area':'House price of unit area'})
data
# Out:
#       No  Transaction_date  HouseAge  Distance to the nearest MRT station  \
# 0      1          2012.917      32.0                             84.87882
# 1      2          2012.917      19.5                            306.59470
# 2      3          2013.583      13.3                            561.98450
# 3      4          2013.500      13.3                            561.98450
# 4      5          2012.833       5.0                            390.56840
# ..   ...               ...       ...                                  ...
# 409  410          2013.000      13.7                           4082.01500
# 410  411          2012.667       5.6                             90.45606
# 411  412          2013.250      18.8                            390.96960
# 412  413          2013.000       8.1                            104.81010
# 413  414          2013.500       6.5                             90.45606
#
#      Number of convenience stores  Latitude  Longitude  \
# 0                              10  24.98298  121.54024
# 1                               9  24.98034  121.53951
# 2                               5  24.98746  121.54391
# 3                               5  24.98746  121.54391
# 4                               5  24.97937  121.54245
# ..                            ...       ...        ...
# 409                             0  24.94155  121.50381
# 410                             9  24.97433  121.54310
# 411                             7  24.97923  121.53986
# 412                             5  24.96674  121.54067
# 413                             9  24.97433  121.54310
#
#      House price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1
# ..                        ...
# 409                      15.4
# 410                      50.0
# 411                      40.6
# 412                      52.5
# 413                      63.9
#
# [414 rows x 8 columns]

# %%
data.head()
# Out:
#    No  Transaction_date  HouseAge  Distance to the nearest MRT station  \
# 0   1          2012.917      32.0                             84.87882
# 1   2          2012.917      19.5                            306.59470
# 2   3          2013.583      13.3                            561.98450
# 3   4          2013.500      13.3                            561.98450
# 4   5          2012.833       5.0                            390.56840
#
#    Number of convenience stores  Latitude  Longitude  House price of unit area
# 0                            10  24.98298  121.54024                      37.9
# 1                             9  24.98034  121.53951                      42.2
# 2                             5  24.98746  121.54391                      47.3
# 3                             5  24.98746  121.54391                      54.8
# 4                             5  24.97937  121.54245                      43.1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   No                                   414 non-null    int64
#  1   Transaction_date                     414 non-null    float64
#  2   HouseAge                             414 non-null    float64
#  3   Distance to the nearest MRT station  414 non-null    float64
#  4   Number of convenience stores         414 non-null    int64
#  5   Latitude                             414 non-null    float64
#  6   Longitude                            414 non-null    float64
#  7   House price of unit area             414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
data.shape
# Out:
# (414, 8)

# %%
data.describe().T
# Out:
#                                      count         mean          std  \
# No                                   414.0   207.500000   119.655756
# Transaction_date                     414.0  2013.148971     0.281967
# HouseAge                             414.0    17.712560    11.392485
# Distance to the nearest MRT station  414.0  1083.885689  1262.109595
# Number of convenience stores         414.0     4.094203     2.945562
# Latitude                             414.0    24.969030     0.012410
# Longitude                            414.0   121.533361     0.015347
# House price of unit area             414.0    37.980193    13.606488
#
#                                             min          25%         50%  \
# No                                      1.00000   104.250000   207.50000
# Transaction_date                     2012.66700  2012.917000  2013.16700
# HouseAge                                0.00000     9.025000    16.10000
# Distance to the nearest MRT station    23.38284   289.324800   492.23130
# Number of convenience stores            0.00000     1.000000     4.00000
# Latitude                               24.93207    24.963000    24.97110
# Longitude                             121.47353   121.528085   121.53863
# House price of unit area                7.60000    27.700000    38.45000
#
#                                              75%         max
# No                                    310.750000   414.00000
# Transaction_date                     2013.417000  2013.58300
# HouseAge                               28.150000    43.80000
# Distance to the nearest MRT station  1454.279000  6488.02100
# Number of convenience stores            6.000000    10.00000
# Latitude                               24.977455    25.01459
# Longitude                             121.543305   121.56627
# House price of unit area               46.600000   117.50000

# %%
data.drop(columns = ['No', 'Latitude','Longitude'], inplace=True)

# %%
data.isnull().mean()*100
# Out:
# Transaction_date                       0.0
# HouseAge                               0.0
# Distance to the nearest MRT station    0.0
# Number of convenience stores           0.0
# House price of unit area               0.0
# dtype: float64

# %% [markdown]
# ## <CENTER> EDA
# ### Univariate Analysis

# %%
for i in data.columns:
    if data[i].dtypes !='object':
        sns.histplot(x=data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes !='object':
        sns.kdeplot(x=data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.boxplot(y=data[i])
        plt.show()

# %% [markdown]
# ### Setting Outliers Limits:

# %%
def outlier_limit(col):
    Q3,Q1=np.nanpercentile(col,[75,25])
    IQR=Q3-Q1
    UL=Q3+1.5*IQR
    LL=Q1-1.5*IQR
    return UL,LL

# %%
for i in data.columns:
    if data[i].dtypes !='object':
        UL,LL=outlier_limit(data[i])
        data[i]=np.where((data[i]>UL)|(data[i]<LL),np.nan,data[i])

# %%
for i in data.columns:
    if data[i].dtypes !='object':
        sns.boxplot(y=data[i],color='red')
        plt.show()

# %%
data.dropna(inplace=True)
data
# Out:
#      Transaction_date  HouseAge  Distance to the nearest MRT station  \
# 0            2012.917      32.0                             84.87882
# 1            2012.917      19.5                            306.59470
# 2            2013.583      13.3                            561.98450
# 3            2013.500      13.3                            561.98450
# 4            2012.833       5.0                            390.56840
# ..                ...       ...                                  ...
# 408          2013.417      18.5                           2175.74400
# 410          2012.667       5.6                             90.45606
# 411          2013.250      18.8                            390.96960
# 412          2013.000       8.1                            104.81010
# 413          2013.500       6.5                             90.45606
#
#      Number of convenience stores  House price of unit area
# 0                            10.0                      37.9
# 1                             9.0                      42.2
# 2                             5.0                      47.3
# 3                             5.0                      54.8
# 4                             5.0                      43.1
# ..                            ...                       ...
# 408                           3.0                      28.1
# 410                           9.0                      50.0
# 411                           7.0                      40.6
# 412                           5.0                      52.5
# 413                           9.0                      63.9
#
# [374 rows x 5 columns]

# %% [markdown]
# ## <CENTER> VISUALIZATION
# ## Barplot

# %%
plt.title('House price of unit area vs Number of convenience stores')
sns.barplot(x='Number of convenience stores',y='House price of unit area',data=data);

# %% [markdown]
# ## Line plot

# %%
sns.lineplot(x="HouseAge",y='House price of unit area',data=data);

# %%
sns.lineplot(x='Number of convenience stores',y='House price of unit area',data=data);

# %% [markdown]
# ## Pie Chart

# %%
data['Number of convenience stores'].value_counts().plot.pie(autopct = '%0.2f%%');

# %% [markdown]
# ### Correlation matrix

# %%
sns.heatmap(data.corr()[['House price of unit area']].sort_values(by='House price of unit area',ascending=False),vmin=-1,vmax=1,annot=True,cmap='autumn');

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374 entries, 0 to 413
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Transaction_date                     374 non-null    float64
#  1   HouseAge                             374 non-null    float64
#  2   Distance to the nearest MRT station  374 non-null    float64
#  3   Number of convenience stores         374 non-null    float64
#  4   House price of unit area             374 non-null    float64
# dtypes: float64(5)
# memory usage: 17.5 KB

# %%
data.columns
# Out:
# Index(['Transaction_date', 'HouseAge', 'Distance to the nearest MRT station',
#        'Number of convenience stores', 'House price of unit area'],
#       dtype='object')

# %%
x=data[['Transaction_date', 'HouseAge', 'Distance to the nearest MRT station',
       'Number of convenience stores']].values

# %%
y=data[['House price of unit area']].values

# %% [markdown]
# ### FEATURE  SCALING

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %% [markdown]
# ### MODEL SELECTION

# %%
models = { 
    "LinearRegression": LinearRegression(), 
    "Ridge":Ridge(),
    "Lasso":Lasso(),
    "LinearSVR":LinearSVR(), 
    "DecisionTreeRegressor":DecisionTreeRegressor(), 
    "GradientBoostingRegressor":GradientBoostingRegressor(), 
    "AdaBoostRegressor":AdaBoostRegressor(), 
    "RandomForestRegressor":RandomForestRegressor() 
}

# %%
for name, model in models.items(): 
    scores = cross_val_score(model, x,y, scoring="neg_mean_squared_error",cv=10,n_jobs=-1) 
    print("cross validation model : {}".format(name)) 
    rmse = np.sqrt(-scores) 
    rmse_average = np.mean(rmse) 
    print("AVERAGE RMSE: ",rmse_average) 
    print("*"*100)
# Out:
# cross validation model : LinearRegression
# AVERAGE RMSE:  7.633641052421474
# ****************************************************************************************************
# cross validation model : Ridge
# AVERAGE RMSE:  7.63341455119254
# ****************************************************************************************************
# cross validation model : Lasso
# AVERAGE RMSE:  7.88021353584236
# ****************************************************************************************************
# cross validation model : LinearSVR
# AVERAGE RMSE:  7.721352431599281
# ****************************************************************************************************
# cross validation model : DecisionTreeRegressor
# AVERAGE RMSE:  8.430258285125428
# ****************************************************************************************************
# cross validation model : GradientBoostingRegressor
# AVERAGE RMSE:  6.429263478086378
# ****************************************************************************************************
# cross validation model : AdaBoostRegressor
# AVERAGE RMSE:  7.0168614997015695
# ****************************************************************************************************
# cross validation model : RandomForestRegressor
# AVERAGE RMSE:  6.489712062764367
# ****************************************************************************************************

# %% [markdown]
# #### WE  CAN  SEE  THAT   " RANDOMFORESTREGRESSOR " IS  HAVING THE  BEST  OVERALL  PERFORMANCE  SO  FAR . WE  MAY  PROCEED  WITH  IT.

# %% [markdown]
# ### SPLITTING THE DATA INTO TRAINING AND TESTING SET

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model = GradientBoostingRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
training_score = model.score(x_train, y_train)*100
training_score
# Out:
# 89.75433335249691

# %%
testing_score = model.score(x_test, y_test)*100
testing_score
# Out:
# 73.51800049412707

# %%
R2_score=r2_score(y_test,model.predict(x_test))*100
R2_score
# Out:
# 73.51800049412707

# %%
mae=mean_absolute_error(y_test,model.predict(x_test))
mae
# Out:
# 4.377678343357208

# %%
mse=mean_squared_error(y_test,model.predict(x_test))
mse
# Out:
# 41.61727716287745

# %%
y_pred=model.predict(x)

# %%
OUTPUT=pd.DataFrame(zip(y,y_pred),columns=("ACTUAL","PREDICTED"),dtype=float)
OUTPUT.head()
# Out:
#    ACTUAL  PREDICTED
# 0    37.9  40.761052
# 1    42.2  47.499141
# 2    47.3  46.026929
# 3    54.8  46.242480
# 4    43.1  46.389975

# %%
plt.figure(figsize=(12,6))
plt.title("PREDICTED VS ACTUAL DATA")
plt.xticks()
sns.scatterplot(data=OUTPUT,x="ACTUAL",y="PREDICTED");

# %% [markdown]
# ## <center> Thank you
